# %%
import os
import boto3
import re
import sagemaker
import pandas as pd
import numpy as np
from pathlib import Path
from sagemaker.image_uris import retrieve
from time import gmtime, strftime
from sagemaker.serializers import CSVSerializer
from sagemaker.deserializers import JSONDeserializer

role = sagemaker.get_execution_role()
region = boto3.Session().region_name

# %% [markdown]
# ## Setting params

# %%
params_cols = ["exp", "imp", "imae", "crude_oil_brent", "gas_henry_hub", "treasury3month", "yuan_dollar_spot_tc", "year", "month"]
params_trainperc = 0.7
# S3 bucket for training data.
# Feel free to specify a different bucket and prefix.
data_bucket = f"x4data"
data_prefix = "linear_regresion"
endpoint_name = 'linear-x'

# %% [markdown]
# ## Preparing the data

# %% [markdown]
# Reading the data

# %%
data = pd.read_csv(Path.cwd().parent.joinpath("input", "data4x_log.csv"))
data.head()
# Out:
#          date       exp       imp       imae  crude_oil_brent  gas_henry_hub  \
# 0  1999-01-01  6.270156  6.290980  52.197280        11.114500       1.849474
# 1  1999-02-01  6.349934  6.274894  48.747353        10.271579       1.771053
# 2  1999-03-01  6.372510  6.396669  50.386924        12.511304       1.791739
# 3  1999-04-01  6.443680  6.192700  47.016367        15.294500       2.150000
# 4  1999-05-01  6.317601  6.250723  48.617007        15.225263       2.260000
#
#    treasury3month  yuan_dollar_spot_tc  year  month
# 0        4.335263             8.278921  1999      1
# 1        4.438421             8.278137  1999      2
# 2        4.440870             8.279152  1999      3
# 3        4.289545             8.279186  1999      4
# 4        4.498500             8.278535  1999      5

# %% [markdown]
# Viewing Na's values

# %%
data.isna().sum()
# Out:
# date                   0
# exp                    2
# imp                    2
# imae                   2
# crude_oil_brent        0
# gas_henry_hub          0
# treasury3month         0
# yuan_dollar_spot_tc    0
# year                   0
# month                  0
# dtype: int64

# %% [markdown]
# We remove the two last rows observations because we have incomplete data

# %%
data2 = data[:(len(data)-2)]
data3 = data2.copy()
data2 = data2.drop("date", axis=1)

# %%
data2.isna().sum()
# Out:
# exp                    0
# imp                    0
# imae                   0
# crude_oil_brent        0
# gas_henry_hub          0
# treasury3month         0
# yuan_dollar_spot_tc    0
# year                   0
# month                  0
# dtype: int64

# %% [markdown]
# Let's split the data into training and test datasets

# %%
rows, train_rows = data2.shape[0], np.ceil(data2.shape[0]*params_trainperc),
val_rows, test_rows = np.ceil((rows-train_rows)/2), data2.shape[0] - (np.ceil((rows-train_rows)/2) + np.ceil(data2.shape[0]*params_trainperc))
print(
      f"The dataset has {rows} rows"
      f"\n"
      f"The train data has {train_rows} rows and ends with {data3.loc[train_rows, ['date']].to_numpy()[0]}"
      f"\n"
      f"The validation data has {val_rows} rows and ends with {data3.loc[(train_rows+test_rows)-1, ['date']].to_numpy()[0]}"
      f"\n"
      f"The test data has {test_rows} rows and ends with {data3.loc[(train_rows+test_rows+val_rows)-1, ['date']].to_numpy()[0]}"
     )
# Out:
# The dataset has 283 rows
# The train data has 199.0 rows and ends with 2015-08-01
# The validation data has 42.0 rows and ends with 2019-01-01
# The test data has 42.0 rows and ends with 2022-07-01

# %%
data2.loc[:train_rows].tail()
# Out:
#           exp       imp       imae  crude_oil_brent  gas_henry_hub  \
# 195  6.660942  7.128043  88.503044        59.524286       2.609048
# 196  6.741396  7.086064  92.093511        64.075000       2.850000
# 197  6.702157  7.070219  92.533938        61.477727       2.783636
# 198  6.633450  7.218925  93.839073        56.561304       2.839565
# 199  6.575134  7.117701  92.746420        46.515000       2.773810
#
#      treasury3month  yuan_dollar_spot_tc  year  month
# 195        0.023182             6.200995  2015      4
# 196        0.016500             6.203450  2015      5
# 197        0.015000             6.205200  2015      6
# 198        0.032273             6.208450  2015      7
# 199        0.071905             6.338252  2015      8

# %%
data2.loc[train_rows+1:(train_rows+val_rows)].head()
# Out:
#           exp       imp       imae  crude_oil_brent  gas_henry_hub  \
# 200  6.559553  7.074705  93.779577        47.623182       2.660909
# 201  6.656148  7.172720  96.666006        48.430000       2.340909
# 202  6.656873  7.185846  98.425855        44.267619       2.092381
# 203  6.586283  7.101069  97.873533        38.005455       1.929565
# 204  6.563484  7.058420  94.535681        30.699500       2.282381
#
#      treasury3month  yuan_dollar_spot_tc  year  month
# 200        0.022381             6.367605  2015      9
# 201        0.015238             6.350500  2015     10
# 202        0.124737             6.364037  2015     11
# 203        0.227727             6.449095  2015     12
# 204        0.255263             6.572600  2016      1

# %%
data2.loc[train_rows+1:(train_rows+val_rows)].tail()
# Out:
#           exp       imp        imae  crude_oil_brent  gas_henry_hub  \
# 237  6.907252  7.357293  106.056533        81.032174       3.275217
# 238  6.853132  7.330153  108.845482        64.748182       4.091000
# 239  6.747685  7.146274  107.932415        57.362353       4.041667
# 240  6.714029  7.206761  101.343809        59.409545       3.108571
# 241  6.789402  7.086702  101.785017        63.960500       2.692632
#
#      treasury3month  yuan_dollar_spot_tc  year  month
# 237        2.249091             6.919105  2018     10
# 238        2.326500             6.936675  2018     11
# 239        2.365789             6.883711  2018     12
# 240        2.374286             6.786345  2019      1
# 241        2.388421             6.736683  2019      2

# %%
data2.loc[(train_rows+val_rows)+1:(train_rows+test_rows+val_rows)].head()
# Out:
#           exp       imp        imae  crude_oil_brent  gas_henry_hub  \
# 242  6.952544  7.267086  105.795411        66.138571       2.948571
# 243  6.859415  7.181361   99.841015        71.233333       2.647143
# 244  6.964854  7.240370  103.663481        71.317727       2.639091
# 245  6.874514  7.115993  103.546382        64.220500       2.398500
# 246  6.827391  7.205442  102.411182        63.919130       2.366190
#
#      treasury3month  yuan_dollar_spot_tc  year  month
# 242        2.402381             6.711943  2019      3
# 243        2.382857             6.716068  2019      4
# 244        2.352727             6.851859  2019      5
# 245        2.170500             6.897675  2019      6
# 246        2.098636             6.877473  2019      7

# %%
data2.loc[(train_rows+val_rows)+1:(train_rows+test_rows+val_rows)].head()
# Out:
#           exp       imp        imae  crude_oil_brent  gas_henry_hub  \
# 242  6.952544  7.267086  105.795411        66.138571       2.948571
# 243  6.859415  7.181361   99.841015        71.233333       2.647143
# 244  6.964854  7.240370  103.663481        71.317727       2.639091
# 245  6.874514  7.115993  103.546382        64.220500       2.398500
# 246  6.827391  7.205442  102.411182        63.919130       2.366190
#
#      treasury3month  yuan_dollar_spot_tc  year  month
# 242        2.402381             6.711943  2019      3
# 243        2.382857             6.716068  2019      4
# 244        2.352727             6.851859  2019      5
# 245        2.170500             6.897675  2019      6
# 246        2.098636             6.877473  2019      7

# %% [markdown]
# Saving the datasets

# %%
train_csv = data2.loc[:train_rows, params_cols]
valid_csv = data2.loc[train_rows+1:(train_rows+val_rows), params_cols]
test_csv = data2.loc[(train_rows+val_rows)+1:(train_rows+test_rows+val_rows), params_cols]
with Path.cwd().parent.joinpath("input", "data4x_log_train.csv") as e:
    train_csv.to_csv(e, sep=',', header=False, index=False)
with Path.cwd().parent.joinpath("input", "data4x_log_validation.csv") as e:
    valid_csv.to_csv(e, sep=',', header=False, index=False)
with Path.cwd().parent.joinpath("input", "data4x_log_test.csv") as e:
    test_csv.to_csv(e, sep=',', header=False, index=False)

# %%
data2.loc[train_rows+1:(train_rows+val_rows)].dtypes
# Out:
# exp                    float64
# imp                    float64
# imae                   float64
# crude_oil_brent        float64
# gas_henry_hub          float64
# treasury3month         float64
# yuan_dollar_spot_tc    float64
# year                     int64
# month                    int64
# dtype: object

# %% [markdown]
# Upload the data to the s3

# %%
s3 = boto3.Session().resource("s3")

file_train = "data4x_log_train.csv"
file_validation = "data4x_log_validation.csv"
file_test = "data4x_log_test.csv"

file_train_full = str(Path.cwd().parent.joinpath("input", file_train))
file_validation_full = str(Path.cwd().parent.joinpath("input", file_validation))
file_test_full = str(Path.cwd().parent.joinpath("input", file_test))

# downloading the train, test, and validation files from data_bucket
with open(file_train_full,'rb') as f:
    s3.Bucket(data_bucket).Object(f"{data_prefix}/train_csv/{file_train}").upload_fileobj(f)
with open(file_validation_full, 'rb') as f:
    s3.Bucket(data_bucket).Object(f"{data_prefix}/validation_csv/{file_validation}").upload_fileobj(f)
with open(file_test_full,'rb') as f:
    s3.Bucket(data_bucket).Object(f"{data_prefix}/test_csv/{file_test}").upload_fileobj(f)

# %% [markdown]
# Creating the chanels, the test will be used in inference

# %%
# creating the inputs for the fit() function with the training and validation location
s3_train_data = f"s3://{data_bucket}/{data_prefix}/train_csv/{file_train}"
print(f"training files will be taken from: {s3_train_data}")
s3_validation_data = f"s3://{data_bucket}/{data_prefix}/validation_csv/{file_validation}"
print(f"validation files will be taken from: {s3_validation_data}")
output_location = f"s3://{data_bucket}/{data_prefix}/model/output"
print(f"training artifacts output location: {output_location}")

# generating the session.s3_input() format for fit() accepted by the sdk
train_data = sagemaker.inputs.TrainingInput(
    s3_train_data,
    distribution="FullyReplicated",
    content_type="text/csv",
    s3_data_type="S3Prefix",
    record_wrapping=None,
    compression=None,
)
validation_data = sagemaker.inputs.TrainingInput(
    s3_validation_data,
    distribution="FullyReplicated",
    content_type="text/csv",
    s3_data_type="S3Prefix",
    record_wrapping=None,
    compression=None,
)
# Out:
# training files will be taken from: s3://x4data/linear_regresion/train_csv/data4x_log_train.csv
# validation files will be taken from: s3://x4data/linear_regresion/validation_csv/data4x_log_validation.csv
# training artifacts output location: s3://x4data/linear_regresion/model/output

# %% [markdown]
# ## Training model

# %% [markdown]
# Set the container

# %%
container = retrieve("linear-learner", boto3.Session().region_name, version="1")
print(container)
# Out:
# 382416733822.dkr.ecr.us-east-1.amazonaws.com/linear-learner:1

# %% [markdown]
# Set the estimator and the hyperparameters

# %%
# %%time

sess = sagemaker.Session()

job_name = "linear-learner-x" + strftime("%Y%m%d-%H-%M-%S", gmtime())
print("Training job", job_name)

linear = sagemaker.estimator.Estimator(
    container,
    role,
    input_mode="File",
    instance_count=1,
    instance_type="ml.m5.large",
    output_path=output_location,
    sagemaker_session=sess,
)

linear.set_hyperparameters(
    feature_dim="auto",
    epochs=16,
    wd=0.01,
    loss="squared_loss",
    predictor_type="regressor",
    normalize_data=True,
    optimizer="adam",
    mini_batch_size=100,
    lr_scheduler_step=100,
    lr_scheduler_factor=0.99,
    lr_scheduler_minimum_lr=0.0001,
    learning_rate=0.1,
)
# Out:
# Training job linear-learner-x20220927-15-49-40
# CPU times: user 17.4 ms, sys: 0 ns, total: 17.4 ms
# Wall time: 18.3 ms

# %% [markdown]
# fitting the data with the channels

# %%
# %%time
linear.fit(inputs={"train": train_data, "validation": validation_data}, job_name=job_name)
# Out:
# 2022-09-27 15:49:40 Starting - Starting the training job...
# 2022-09-27 15:50:04 Starting - Preparing the instances for trainingProfilerReport-1664293780: InProgress
# ......
# 2022-09-27 15:51:08 Downloading - Downloading input data......
# 2022-09-27 15:52:05 Training - Downloading the training image.........
# 2022-09-27 15:53:40 Training - Training image download completed. Training in progress..Docker entrypoint called with argument(s): train
# Running default environment configuration script
# [09/27/2022 15:53:43 INFO 140086914156352] Reading default configuration from /opt/amazon/lib/python3.7/site-packages/algorithm/resources/default-input.json: {'mini_batch_size': '1000', 'epochs': '15', 'feature_dim': 'auto', 'use_bias': 'true', 'binary_classifier_model_selection_criteria': 'accuracy', 'f_beta': '1.0', 'target_recall': '0.8', 'target_precision': '0.8', 'num_models': 'auto', 'num_calibration_samples': '10000000', 'init_method': 'uniform', 'init_scale': '0.07', 'init_sigma': '0.01', 'init_bias': '0.0', 'optimizer': 'auto', 'loss': 'auto', 'margin': '1.0', 'quantile': '0.5', 'loss_insensitivity': '0.01', 'huber_delta': '1.0', 'num_classes': '1', 'accuracy_top_k': '3', 'wd': 'auto', 'l1': 'auto', 'momentum': 'auto', 'learning_rate': 'auto', 'beta_1': 'auto', 'beta_2': 'auto', 'bias_lr_mult': 'auto', 'bias_wd_mult': 'auto', 'use_lr_scheduler': 'true', 'lr_scheduler_step': 'auto', 'lr_scheduler_factor': 'auto', 'lr_scheduler_minimum_lr': 'auto', 'positive_example_weight_mult': '1.0', 'balance_multiclass_weights': 'false', 'normalize_data': 'true', 'normalize_label': 'auto', 'unbias_data': 'auto', 'unbias_label': 'auto', 'num_point_for_scaler': '10000', '_kvstore': 'auto', '_num_gpus': 'auto', '_num_kv_servers': 'auto', '_log_level': 'info', '_tuning_objective_metric': '', 'early_stopping_patience': '3', 'early_stopping_tolerance': '0.001', '_enable_profiler': 'false'}
# [09/27/2022 15:53:43 INFO 140086914156352] Merging with provided configuration from /opt/ml/input/config/hyperparameters.json: {'epochs': '16', 'feature_dim': 'auto', 'learning_rate': '0.1', 'loss': 'squared_loss', 'lr_scheduler_factor': '0.99', 'lr_scheduler_minimum_lr': '0.0001', 'lr_scheduler_step': '100', 'mini_batch_size': '100', 'normalize_data': 'True', 'optimizer': 'adam', 'predictor_type': 'regressor', 'wd': '0.01'}
# [09/27/2022 15:53:43 INFO 140086914156352] Final configuration: {'mini_batch_size': '100', 'epochs': '16', 'feature_dim': 'auto', 'use_bias': 'true', 'binary_classifier_model_selection_criteria': 'accuracy', 'f_beta': '1.0', 'target_recall': '0.8', 'target_precision': '0.8', 'num_models': 'auto', 'num_calibration_samples': '10000000', 'init_method': 'uniform', 'init_scale': '0.07', 'init_sigma': '0.01', 'init_bias': '0.0', 'optimizer': 'adam', 'loss': 'squared_loss', 'margin': '1.0', 'quantile': '0.5', 'loss_insensitivity': '0.01', 'huber_delta': '1.0', 'num_classes': '1', 'accuracy_top_k': '3', 'wd': '0.01', 'l1': 'auto', 'momentum': 'auto', 'learning_rate': '0.1', 'beta_1': 'auto', 'beta_2': 'auto', 'bias_lr_mult': 'auto', 'bias_wd_mult': 'auto', 'use_lr_scheduler': 'true', 'lr_scheduler_step': '100', 'lr_scheduler_factor': '0.99', 'lr_scheduler_minimum_lr': '0.0001', 'positive_example_weight_mult': '1.0', 'balance_multiclass_weights': 'false', 'normalize_data': 'True', 'normalize_label': 'auto', 'unbias_data': 'auto', 'unbias_label': 'auto', 'num_point_for_scaler': '10000', '_kvstore': 'auto', '_num_gpus': 'auto', '_num_kv_servers': 'auto', '_log_level': 'info', '_tuning_objective_metric': '', 'early_stopping_patience': '3', 'early_stopping_tolerance': '0.001', '_enable_profiler': 'false', 'predictor_type': 'regressor'}
# [09/27/2022 15:53:48 WARNING 140086914156352] Loggers have already been setup.
# [09/27/2022 15:53:48 INFO 140086914156352] Final configuration: {'mini_batch_size': '100', 'epochs': '16', 'feature_dim': 'auto', 'use_bias': 'true', 'binary_classifier_model_selection_criteria': 'accuracy', 'f_beta': '1.0', 'target_recall': '0.8', 'target_precision': '0.8', 'num_models': 'auto', 'num_calibration_samples': '10000000', 'init_method': 'uniform', 'init_scale': '0.07', 'init_sigma': '0.01', 'init_bias': '0.0', 'optimizer': 'adam', 'loss': 'squared_loss', 'margin': '1.0', 'quantile': '0.5', 'loss_insensitivity': '0.01', 'huber_delta': '1.0', 'num_classes': '1', 'accuracy_top_k': '3', 'wd': '0.01', 'l1': 'auto', 'momentum': 'auto', 'learning_rate': '0.1', 'beta_1': 'auto', 'beta_2': 'auto', 'bias_lr_mult': 'auto', 'bias_wd_mult': 'auto', 'use_lr_scheduler': 'true', 'lr_scheduler_step': '100', 'lr_scheduler_factor': '0.99', 'lr_scheduler_minimum_lr': '0.0001', 'positive_example_weight_mult': '1.0', 'balance_multiclass_weights': 'false', 'normalize_data': 'True', 'normalize_label': 'auto', 'unbias_data': 'auto', 'unbias_label': 'auto', 'num_point_for_scaler': '10000', '_kvstore': 'auto', '_num_gpus': 'auto', '_num_kv_servers': 'auto', '_log_level': 'info', '_tuning_objective_metric': '', 'early_stopping_patience': '3', 'early_stopping_tolerance': '0.001', '_enable_profiler': 'false', 'predictor_type': 'regressor'}
# [09/27/2022 15:53:48 WARNING 140086914156352] Loggers have already been setup.
# Process 1 is a worker.
# [09/27/2022 15:53:48 INFO 140086914156352] Using default worker.
# [09/27/2022 15:53:49 INFO 140086914156352] Checkpoint loading and saving are disabled.
# [09/27/2022 15:53:49 INFO 140086914156352] Create Store: local
# [09/27/2022 15:53:49 INFO 140086914156352] Scaler algorithm parameters
#  <algorithm.scaler.ScalerAlgorithmStable object at 0x7f67ffaf4f90>
# [09/27/2022 15:53:49 INFO 140086914156352] Scaling model computed with parameters:
#  {'stdev_label':
# [0.29019317]
# <NDArray 1 @cpu(0)>, 'stdev_weight':
# [ 0.38241985 12.91121    33.964966    2.2298632   2.0045412   0.8727803
#   4.8139563   3.4356368 ]
# <NDArray 8 @cpu(0)>, 'mean_label':
# [6.2554216]
# <NDArray 1 @cpu(0)>, 'mean_weight':
# [6.6604853e+00 6.9948204e+01 6.3648956e+01 4.9058485e+00 1.9174972e+00
#  7.3932242e+00 2.0068401e+03 6.4200001e+00]
# <NDArray 8 @cpu(0)>}
# [09/27/2022 15:53:49 INFO 140086914156352] nvidia-smi: took 0.036 seconds to run.
# [09/27/2022 15:53:49 INFO 140086914156352] nvidia-smi identified 0 GPUs.
# [09/27/2022 15:53:49 INFO 140086914156352] Number of GPUs being used: 0
# #metrics {"StartTime": 1664294029.2810764, "EndTime": 1664294029.2811286, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "Meta": "init_train_data_iter"}, "Metrics": {"Total Records Seen": {"sum": 300.0, "count": 1, "min": 300, "max": 300}, "Total Batches Seen": {"sum": 3.0, "count": 1, "min": 3, "max": 3}, "Max Records Seen Between Resets": {"sum": 200.0, "count": 1, "min": 200, "max": 200}, "Max Batches Seen Between Resets": {"sum": 2.0, "count": 1, "min": 2, "max": 2}, "Reset Count": {"sum": 2.0, "count": 1, "min": 2, "max": 2}, "Number of Records Since Last Reset": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Number of Batches Since Last Reset": {"sum": 0.0, "count": 1, "min": 0, "max": 0}}}
# #metrics {"StartTime": 1664294029.3801699, "EndTime": 1664294029.3802664, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 0}, "Metrics": {"train_mse_objective": {"sum": 1.454310188293457, "count": 1, "min": 1.454310188293457, "max": 1.454310188293457}}}
# #metrics {"StartTime": 1664294029.3809123, "EndTime": 1664294029.3809462, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 1}, "Metrics": {"train_mse_objective": {"sum": 0.9124546051025391, "count": 1, "min": 0.9124546051025391, "max": 0.9124546051025391}}}
# #metrics {"StartTime": 1664294029.3813312, "EndTime": 1664294029.3813837, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 2}, "Metrics": {"train_mse_objective": {"sum": 0
, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 17}, "Metrics": {"validation_mse_objective": {"sum": 0.23910213652111234, "count": 1, "min": 0.23910213652111234, "max": 0.23910213652111234}}}
# #metrics {"StartTime": 1664294029.7909791, "EndTime": 1664294029.79099, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 18}, "Metrics": {"validation_mse_objective": {"sum": 0.2661590576171875, "count": 1, "min": 0.2661590576171875, "max": 0.2661590576171875}}}
# #metrics {"StartTime": 1664294029.7910285, "EndTime": 1664294029.7910392, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 19}, "Metrics": {"validation_mse_objective": {"sum": 0.2785593214489165, "count": 1, "min": 0.2785593214489165, "max": 0.2785593214489165}}}
# #metrics {"StartTime": 1664294029.7910783, "EndTime": 1664294029.791089, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 20}, "Metrics": {"validation_mse_objective": {"sum": 0.006801552715755645, "count": 1, "min": 0.006801552715755645, "max": 0.006801552715755645}}}
# #metrics {"StartTime": 1664294029.7911253, "EndTime": 1664294029.7911358, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 21}, "Metrics": {"validation_mse_objective": {"sum": 0.007644163001151312, "count": 1, "min": 0.007644163001151312, "max": 0.007644163001151312}}}
# #metrics {"StartTime": 1664294029.7911742, "EndTime": 1664294029.7911847, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 22}, "Metrics": {"validation_mse_objective": {"sum": 0.006690299227124169, "count": 1, "min": 0.006690299227124169, "max": 0.006690299227124169}}}
# #metrics {"StartTime": 1664294029.7912223, "EndTime": 1664294029.7912405, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 23}, "Metrics": {"validation_mse_objective": {"sum": 0.0064626045170284455, "count": 1, "min": 0.0064626045170284455, "max": 0.0064626045170284455}}}
# #metrics {"StartTime": 1664294029.7912798, "EndTime": 1664294029.7912898, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 24}, "Metrics": {"validation_mse_objective": {"sum": 0.2785617510477702, "count": 1, "min": 0.2785617510477702, "max": 0.2785617510477702}}}
# ...
# #metrics {"StartTime": 1664294032.3224118, "EndTime": 1664294032.3224356, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 12, "model": 31}, "Metrics": {"train_mse_objective": {"sum": 0.9721014595031738, "count": 1, "min": 0.9721014595031738, "max": 0.9721014595031738}}}
# [09/27/2022 15:53:52 INFO 140086914156352] #quality_metric: host=algo-1, epoch=12, train mse_objective <loss>=0.2028244924545288
# #metrics {"StartTime": 1664294032.4225833, "EndTime": 1664294032.4227133, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 12, "model": 0}, "Metrics": {"validation_mse_objective": {"sum": 0.02369648785818191, "count": 1, "min": 0.02369648785818191, "max": 0.02369648785818191}}}
# #metrics {"StartTime": 1664294032.4231575, "EndTime": 1664294032.4232059, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 12, "model": 1}, "Metrics": {"validation_mse_objective": {"sum": 0.07422453448885963, "count": 1, "min": 0.07422453448885963, "max": 0.07422453448885963}}}
# #metrics {"StartTime": 1664294032.4235907, "EndTime": 1664294032.4236152, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 12, "model": 2}, "Metrics": {"validation_mse_objective": {"sum": 0.07945491018749419, "count": 1, "min": 0.07945491018749419, "max": 0.07945491018749419}}}
# #metrics {"StartTime": 1664294032.4239497, "EndTime": 1664294032.423976, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 12, "model": 3}, "Metrics": {"validation_mse_objective": {"sum": 0.04933847132183257, "count": 1, "min": 0.04933847132183257, "max": 0.04933847132183257}}}
# #metrics {"StartTime": 1664294032.4243047, "EndTime": 1664294032.4243302, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 12, "model": 4}, "Metrics": {"validation_mse_objective": {"sum": 0.020112477597736177, "count": 1, "min": 0.020112477597736177, "max": 0.020112477597736177}}}
# #metrics {"StartTime": 1664294032.424695, "EndTime": 1664294032.4247212, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 12, "model": 5}, "Metrics": {"validation_mse_objective": {"sum": 0.03187511648450579, "count": 1, "min": 0.03187511648450579, "max": 0.03187511648450579}}}
# #metrics {"StartTime": 1664294032.4257176, "EndTime": 1664294032.4257436, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 12, "model": 6}, "Metrics": {"validation_mse_objective": {"sum": 0.02183260378383455, "count": 1, "min": 0.02183260378383455, "max": 0.02183260378383455}}}
# #metrics {"StartTime": 1664294032.4259915, "EndTime": 1664294032.4260137, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 12, "model": 7}, "Metrics": {"validation_mse_objective": {"sum": 0.01885268801734561, "count": 1, "min": 0.01885268801734561, "max": 0.01885268801734561}}}
# #metrics {"StartTime": 1664294032.4263897, "EndTime": 1664294032.4264145, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 12, "model": 8}, "Metrics": {"validation_mse_objective": {"sum": 0.056191472780136836, "count": 1, "min": 0.056191472780136836, "max": 0.056191472780136836}}}
# #metrics {"StartTime": 1664294032.426731, "EndTime": 1664294032.426756, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 12, "model": 9}, "Metrics": {"validation_mse_objective": {"sum": 0.07843341713859922, "count": 1, "min": 0.07843341713859922, "max": 0.07843341713859922}}}
# #metrics {"StartTime": 1664294032.4270718, "EndTime": 1664294032.4270966, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 12, "model": 10}, "Metrics": {"validation_mse_objective": {"sum": 0.053967441831316264, "count": 1, "min": 0.053967441831316264, "max": 0.053967441831316264}}}
# #metrics {"StartTime": 1664294032.4274414, "EndTime": 1664294032.4274685, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 12, "model": 11}, "Metrics": {"validation_mse_objective": {"sum": 0.07779320648738317, "count": 1, "min": 0.07779320648738317, "max": 0.07779320648738317}}}
# #metrics {"StartTime": 1664294032.4277797, "EndTime": 1664294032.4278245, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 12, "model": 12}, "Metrics": {"validation_mse_objective": {"sum": 0.037811415536063056, "count": 1, "min": 0.037811415536063056, "max": 0.037811415536063056}}}
# #metrics {"StartTime": 1664294032.4281254, "EndTime": 1664294032.4281533, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 12, "model": 13}, "Metrics": {"validation_mse_objective": {"sum": 0.03128515822546823, "count": 1, "min": 0.03128515822546823, "max": 0.03128515822546823}}}
# #metrics {"StartTime": 1664294032.428478, "EndTime": 1664294032.4285033, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 12, "model": 14}, "Metrics": {"validation_mse_objective": {"sum": 0.03432720048086984, "count": 1, "min": 0.03432720048086984, "max": 0.03432720048086984}}}
# #metrics {"StartTime": 1664294032.4289746, "EndTime": 1664294032.429, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 12, "model": 15}, "Metrics": {"validation_mse_objective": {"sum": 0.030303310780298142, "count": 1, "min": 0.030303310780298142, "max": 0.030303310780298142}}}
# #metrics {"StartTime": 1664294032.4293475, "EndTime": 1664294032.429371, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 12, "model": 16}, "Metrics": {"validation_mse_objective": {"sum": 0.08404966763087682, "count": 1, "min": 0.08404966763087682, "max": 0.08404966763087682}}}
# #metrics {"StartTime": 1664294032.4299743, "EndTime": 1664294032.430004, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 12, "model": 17}, "Metrics": {"validation_mse_objective": {"sum": 0.08907474790300642, "count": 1, "min": 0.08907474790300642, "max": 0.08907474790300642}}}
# #metrics {"StartTime": 1664294032.430339, "EndTime": 1664294032.4303706, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 12, "model": 18}, "Metrics": {"validation_mse_objective": {"sum": 0.09342868555159796, "count": 1, "min": 0.09342868555159796, "max": 0.09342868555159796}}}
# #metrics {"StartTime": 1664294032.4306943, "EndTime": 1664294032.4307177, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 12, "model": 19}, "Metrics": {"validation_mse_objective": {"sum": 0.09700615065438407, "count": 1, "min": 0.09700615065438407, "max": 0.09700615065438407}}}
# #metrics {"StartTime": 1664294032.4310956, "EndTime": 1664294032.431122, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 12, "model": 20}, "Metrics": {"validation_mse_objective": {"sum": 0.09934096109299433, "count": 1, "min": 0.09934096109299433, "max": 0.09934096109299433}}}
# #metrics {"StartTime": 1664294032.431546, "EndTime": 1664294032.4315715, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 12, "model": 21}, "Metrics": {"validation_mse_objective": {"sum": 0.11118678819565546, "count": 1, "min": 0.11118678819565546, "max": 0.11118678819565546}}}
# #metrics {"StartTime": 1664294032.4318824, "EndTime": 1664294032.4319072, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 12, "model": 22}, "Metrics": {"validation_mse_objective": {"sum": 0.0954449630918957, "count": 1, "min": 0.0954449630918957, "max": 0.0954449630918957}}}
# #metrics {"StartTime": 1664294032.4327073, "EndTime": 1664294032.4327335, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 12, "model": 23}, "Metrics": {"validation_mse_objective": {"sum": 0.08628206593649727, "count": 1, "min": 0.08628206593649727, "max": 0.08628206593649727}}}
# #metrics {"StartTime": 1664294032.432953, "EndTime": 1664294032.4329743, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 12, "model": 24}, "Metrics": {"validation_mse_objective": {"sum": 0.25445981252761113, "count": 1, "min": 0.25445981252761113, "max": 0.25445981252761113}}}
# #metrics {"StartTime": 1664294032.4331875, "EndTime": 1664294032.4332762, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 12, "model": 25}, "Metrics": {"validation_mse_objective": {"sum": 0.24942643301827566, "count": 1, "min": 0.24942643301827566, "max": 0.24942643301827566}}}
# #metrics {"StartTime": 1664294032.4335618, "EndTime": 1664294032.4335866, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 12, "model": 26}, "Metrics": {"validation_mse_objective": {"sum": 0.24567422412690662, "count": 1, "min": 0.24567422412690662, "max": 0.24567422412690662}}}
# #metrics {"StartTime": 1664294032.4338923, "EndTime": 1664294032.4339173, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 12, "model": 27}, "Metrics": {"validation_mse_objective": {"sum": 0.2568686576116653, "count": 1, "min": 0.2568686576116653, "max": 0.2568686576116653}}}
# #metrics {"StartTime": 1664294032.4342306, "EndTime": 1664294032.434256, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 12, "model": 28}, "Metrics": {"validation_mse_objective": {"sum": 0.21236456008184523, "count": 1, "min": 0.21236456008184523, "max": 0.21236456008184523}}}
# #metrics {"StartTime": 1664294032.4345727, "EndTime": 1664294032.4345987, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 12, "model": 29}, "Metrics": {"validation_mse_objective": {"sum": 0.23999997547694615, "count": 1, "min": 0.23999997547694615, "max": 0.23999997547694615}}}
# #metrics {"StartTime": 1664294032.434922, "EndTime": 1664294032.4349499, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 12, "model": 30}, "Metrics": {"validation_mse_objective": {"sum": 0.21371030807495117, "count": 1, "min": 0.21371030807495117, "max": 0.21371030807495117}}}
# #metrics {"StartTime": 1664294032.4353814, "EndTime": 1664294032.4354608, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 12, "model": 31}, "Metrics": {"validation_mse_objective": {"sum": 0.21374307359967912, "count": 1, "min": 0.21374307359967912, "max": 0.21374307359967912}}}
# [09/27/2022 15:53:52 INFO 140086914156352] #quality_metric: host=algo-1, epoch=12, validation mse_objective <loss>=0.02369648785818191
# [09/27/2022 15:53:52 INFO 140086914156352] #early_stopping_criteria_metric: host=algo-1, epoch=12, criteria=mse_objective, value=0.01885268801734561
# [09/27/2022 15:53:52 INFO 140086914156352] Saving model for epoch: 12
# [09/27/2022 15:53:52 INFO 140086914156352] Saved checkpoint to "/tmp/tmp007eg4hw/mx-mod-0000.params"
# [09/27/2022 15:53:52 INFO 140086914156352] Early stop condition met. Stopping training.
# [09/27/2022 15:53:52 INFO 140086914156352] #progress_metric: host=algo-1, completed 100 % epochs
# #metrics {"StartTime": 1664294032.226902, "EndTime": 1664294032.452164, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 12, "Meta": "training_data_iter"}, "Metrics": {"Total Records Seen": {"sum": 2900.0, "count": 1, "min": 2900, "max": 2900}, "Total Batches Seen": {"sum": 29.0, "count": 1, "min": 29, "max": 29}, "Max Records Seen Between Resets": {"sum": 200.0, "count": 1, "min": 200, "max": 200}, "Max Batches Seen Between Resets": {"sum": 2.0, "count": 1, "min": 2, "max": 2}, "Reset Count": {"sum": 15.0, "count": 1, "min": 15, "max": 15}, "Number of Records Since Last Reset": {"sum": 200.0, "count": 1, "min": 200, "max": 200}, "Number of Batches Since Last Reset": {"sum": 2.0, "count": 1, "min": 2, "max": 2}}}
# [09/27/2022 15:53:52 INFO 140086914156352] #throughput_metric: host=algo-1, train throughput=886.3299744411444 records/second
# [09/27/2022 15:53:52 WARNING 140086914156352] wait_for_all_workers will not sync workers since the kv store is not running distributed
# [09/27/2022 15:53:52 WARNING 140086914156352] wait_for_all_workers will not sync workers since the kv store is not running distributed
# [09/27/2022 15:53:52 INFO 140086914156352] #early_stopping_criteria_metric: host=algo-1, epoch=12, criteria=mse_objective, value=0.01885268801734561
# [09/27/2022 15:53:52 INFO 140086914156352] #validation_score (algo-1) : ('mse_objective', 0.005050045393762134)
# [09/27/2022 15:53:52 INFO 140086914156352] #validation_score (algo-1) : ('mse', 0.005050045393762134)
# [09/27/2022 15:53:52 INFO 140086914156352] #validation_score (algo-1) : ('absolute_loss', 0.054929438091459726)
# [09/27/2022 15:53:52 INFO 140086914156352] #validation_score (algo-1) : ('rmse', 0.07106367140643759)
# [09/27/2022 15:53:52 INFO 140086914156352] #validation_score (algo-1) : ('r2', 0.48671054697348226)
# [09/27/2022 15:53:52 INFO 140086914156352] #validation_score (algo-1) : ('mae', 0.054929438091459726)
# [09/27/2022 15:53:52 INFO 140086914156352] #quality_metric: host=algo-1, validation mse_objective <loss>=0.005050045393762134
# [09/27/2022 15:53:52 INFO 140086914156352] #quality_metric: host=algo-1, validation mse <loss>=0.005050045393762134
# [09/27/2022 15:53:52 INFO 140086914156352] #quality_metric: host=algo-1, validation absolute_loss <loss>=0.054929438091459726
# [09/27/2022 15:53:52 INFO 140086914156352] #quality_metric: host=algo-1, validation rmse <loss>=0.07106367140643759
# [09/27/2022 15:53:52 INFO 140086914156352] #quality_metric: host=algo-1, validation r2 <loss>=0.48671054697348226
# [09/27/2022 15:53:52 INFO 140086914156352] #quality_metric: host=algo-1, validation mae <loss>=0.054929438091459726
# [09/27/2022 15:53:52 INFO 140086914156352] Best model found for hyperparameters: {"optimizer": "adam", "learning_rate": 0.1, "wd": 0.01, "l1": 0.0, "lr_scheduler_step": 10, "lr_scheduler_factor": 0.99, "lr_scheduler_minimum_lr": 0.0001}
# [09/27/2022 15:53:52 INFO 140086914156352] Saved checkpoint to "/tmp/tmpu6itgqwt/mx-mod-0000.params"
# [09/27/2022 15:53:52 INFO 140086914156352] Test data is not provided.
# #metrics {"StartTime": 1664294029.0430899, "EndTime": 1664294032.6099727, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training"}, "Metrics": {"initialize.time": {"sum": 218.8253402709961, "count": 1, "min": 218.8253402709961, "max": 218.8253402709961}, "epochs": {"sum": 16.0, "count": 1, "min": 16, "max": 16}, "check_early_stopping.time": {"sum": 15.901565551757812, "count": 14, "min": 0.2589225769042969, "max": 3.383636474609375}, "update.time": {"sum": 3066.6284561157227, "count": 13, "min": 180.94754219055176, "max": 291.28098487854004}, "finalize.time": {"sum": 143.69630813598633, "count": 1, "min": 143.69630813598633, "max": 143.69630813598633}, "setuptime": {"sum": 4.064798355102539, "count": 1, "min": 4.064798355102539, "max": 4.064798355102539}, "totaltime": {"sum": 3801.522731781006, "count": 1, "min": 3801.522731781006, "max": 3801.522731781006}}}
#
# 2022-09-27 15:54:05 Uploading - Uploading generated training model
# 2022-09-27 15:54:25 Completed - Training job completed
# ProfilerReport-1664293780: NoIssuesFound
# Training seconds: 188
# Billable seconds: 188
# CPU times: user 691 ms, sys: 61.9 ms, total: 753 ms
# Wall time: 5min 16s

# %% [markdown]
# After training we can deploy the model to an endpoint, where we can do inference (predictions)

# %%
# %%time
# creating the endpoint out of the trained model
linear_predictor = linear.deploy(endpoint_name=endpoint_name, initial_instance_count=1, instance_type="ml.m4.xlarge")
print(f"\ncreated endpoint: {linear_predictor.endpoint_name}")
# Out:
# ----------!
# created endpoint: linear-x
# CPU times: user 138 ms, sys: 21.2 ms, total: 160 ms
# Wall time: 5min 1s

# %% [markdown]
# ## Inference

# %% [markdown]
# Check for last observation

# %%
# configure the predictor to accept to serialize csv input and parse the reponse as json
linear_predictor.serializer = CSVSerializer()
linear_predictor.deserializer = JSONDeserializer()

test_data = [l for l in open(file_test_full, "r")]
# we select the last row 
sample = test_data[len(test_data)-1].split(",")
actual_exp = sample[0]
payload = sample[1:]  # removing actual age from the sample
payload = [s.replace("\n", "") for s in payload]
payload = ",".join(map(str, payload))
# payload
print(f"The values to send {payload}")
# Invoke the predicor and analyise the result
result = linear_predictor.predict(payload)
# extracting the prediction value
result = round(float(result["predictions"][0]["score"]), 2)
# compare
accuracy = str(round(100 - ((abs(float(result) - float(actual_exp)) / float(actual_exp)) * 100), 2))
print(f"Actual exp: {actual_exp}\nPrediction: {result}\nAccuracy: {accuracy}")
# transforming to exp
print(f"The actual exp in millions dollars: {np.exp(pd.to_numeric(actual_exp))}\nPrediction in millions dollars: {np.exp(result)}")

# %%
client = boto3.client(service_name='sagemaker-runtime')

# %%
test_data = [l for l in open(file_test_full, "r")]
# we select the last row 
sample = test_data[len(test_data)-1].split(",")
actual_exp = sample[0]
payload = sample[1:]  # removing actual age from the sample
payload = [s.replace("\n", "") for s in payload]
payload = ",".join(map(str, payload))
payload
# Out:
# '7.489476421824656,108.78198124,111.92571428571428,7.284499999999999,2.2325,6.735155000000001,2022,7'

# %%
response = client.invoke_endpoint(EndpointName=endpoint_name,ContentType='Text/CSV', Body=payload)
print(response["Body"].read())
# Out:
# b'{"predictions": [{"score": 6.950959205627441}]}'

# %% [markdown]
# Check the all the test data. First some funs

# %%
import io
import json
def np2csv(arr):
    csv = io.BytesIO()
    np.savetxt(csv, arr, delimiter=",", fmt="%g")
    return csv.getvalue().decode().rstrip()

def pred(csv):
    payload = np2csv(csv)
    response = linear_predictor.predict(payload)
    test_pred = np.array([r["score"] for r in response["predictions"]])
    return test_pred

# %% [markdown]
# Prepare the data

# %%
train_y = train_csv.loc[:, "exp"]
train_csv2 = train_csv.drop("exp", axis=1)
valid_y = valid_csv.loc[:, "exp"]
valid_csv2 = valid_csv.drop("exp", axis=1)
test_y = test_csv.loc[:, "exp"]
test_csv2 = test_csv.drop("exp", axis=1)

# %% [markdown]
# Create the predict data

# %%
train_pred, valid_pred, test_pred = pred(train_csv2), pred(valid_csv2), pred(test_csv2)

# %%
from sklearn.metrics import mean_squared_error
train_rms = mean_squared_error(train_y, train_pred, squared=False)
valid_rms = mean_squared_error(valid_y, valid_pred, squared=False)
test_rms = mean_squared_error(test_y, test_pred, squared=False)
print("Train RMSE Linear:", round(train_rms, 3))
print("Validation RMSE Linear:", round(valid_rms, 3))
print("Test RMSE Linear:", round(test_rms, 3))
# Out:
# Train RMSE Linear: 0.146
# Validation RMSE Linear: 0.071
# Test RMSE Linear: 0.179

# %% [markdown]
# ## Delete endpoint

# %%
#sagemaker.Session().delete_endpoint(linear_predictor.endpoint_name)
#print(f"deleted {linear_predictor.endpoint_name} successfully!")
